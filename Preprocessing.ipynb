# %% [markdown]
# ### 전처리하기

# %%
import numpy as np
import pandas as pd

adr_df = pd.read_excel("./data/광진구_데이터프레임.xlsx",index_col=0)

# %%
adr_df.set_index("지번주소",inplace=True) # 인덱스 설정
adr_df.drop(columns=["도로명주소","위도","경도","소지역코드","지하철이름","주차장과의최단거리"],inplace=True) # 안쓸 데이터 드랍

# %%
adr_df.info() # 타입확인 및 결측치 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23216 entries, 서울특별시 광진구 광장동  102 to 서울특별시 광진구 화양동  99
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   인구밀도                  23216 non-null  float64
#  1   총 사업체수                23216 non-null  int64
#  2   반경 1km 이내 불법주정차 단속 수  23216 non-null  int64
#  3   토지면적                  23216 non-null  object
#  4   공시지가_기준년월             23213 non-null  object
#  5   공시지가(원/면적)            23213 non-null  float64
#  6   역과의최단거리               23216 non-null  int64
#  7   반경 1km 이내 주차장수        23216 non-null  int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 결측치 삭제

# %%
adr_df.dropna(inplace=True)

# %% [markdown]
# ### 타입변환

# %%
adr_df["토지면적"] = pd.to_numeric(adr_df["토지면적"])

# %%
adr_df["공시지가(원/면적)"] = adr_df["공시지가(원/면적)"].astype(int)

# %% [markdown]
# ### 공시지가_기준년월 2013->0, 2014-> 1, 2015-> 2, 2016-> 3, 2022/01-> 4, 2022/07->5

# %%
adr_df["공시지가_기준년월"].unique()
# Out:
# array(['2022년01월', '2022년07월', '2014년01월', '2013년01월', '2016년01월',
#        '2015년01월'], dtype=object)

# %%
adr_df["공시지가_기준년월"].replace({"2013년01월":0,"2014년01월":1,"2015년01월":2,"2016년01월":3,"2022년01월":4,"2022년07월":5},inplace=True)

# %%
adr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23213 entries, 서울특별시 광진구 광장동  102 to 서울특별시 광진구 화양동  99
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   인구밀도                  23213 non-null  float64
#  1   총 사업체수                23213 non-null  int64
#  2   반경 1km 이내 불법주정차 단속 수  23213 non-null  int64
#  3   토지면적                  23213 non-null  float64
#  4   공시지가_기준년월             23213 non-null  int64
#  5   공시지가(원/면적)            23213 non-null  int32
#  6   역과의최단거리               23213 non-null  int64
#  7   반경 1km 이내 주차장수        23213 non-null  int64
# dtypes: float64(2), int32(1), int64(5)
# memory usage: 1.5+ MB

# %%
adr_df
# Out:
#                         인구밀도  총 사업체수  반경 1km 이내 불법주정차 단속 수    토지면적  공시지가_기준년월  \
# 지번주소
# 서울특별시 광진구 광장동  102    7067.7     136                     2  2211.8          4
# 서울특별시 광진구 광장동  104    7067.7     136                     2   172.1          5
# 서울특별시 광진구 광장동  105    7067.7     136                     2   848.8          4
# 서울특별시 광진구 광장동  106    7067.7     136                     2   452.8          4
# 서울특별시 광진구 광장동  107    7067.7     136                     2   403.9          4
# ...                      ...     ...                   ...     ...        ...
# 서울특별시 광진구 화양동  95-5  52366.1      44                    28   152.0          4
# 서울특별시 광진구 화양동  96-2  52366.1      44                    31   165.0          4
# 서울특별시 광진구 화양동  97    52366.1      44                    28   188.0          4
# 서울특별시 광진구 화양동  98-1  52366.1      44                    28   299.0          4
# 서울특별시 광진구 화양동  99    52366.1      44                    26   315.0          4
#
#                      공시지가(원/면적)  역과의최단거리  반경 1km 이내 주차장수
# 지번주소
# 서울특별시 광진구 광장동  102      6324000     1144              41
# 서울특별시 광진구 광장동  104      5097000     1166              41
# 서울특별시 광진구 광장동  105      5202000     1068              41
# 서울특별시 광진구 광장동  106      5097000     1038              41
# 서울특별시 광진구 광장동  107      5793000     1011              42
# ...                         ...      ...             ...
# 서울특별시 광진구 화양동  95-5     4346000      630              75
# 서울특별시 광진구 화양동  96-2     4346000      630              75
# 서울특별시 광진구 화양동  97       5095000      633              74
# 서울특별시 광진구 화양동  98-1     5095000      647              73
# 서울특별시 광진구 화양동  99       4847000      680              74
#
# [23213 rows x 8 columns]

# %% [markdown]
# ### EDA

# %% [markdown]
# ### 폰트 설정하기

# %%
def get_font():
    import matplotlib.font_manager as font_manager
    import matplotlib as mpl
# Add every font at the specified location
    font_dir = ['C:/Users/gihun/Fonts/']
    for font in font_manager.findSystemFonts(fontpaths=font_dir):
        print(mpl.font_manager.FontProperties(fname=font).get_name())
        font_manager.fontManager.addfont(font)
# Set font family globally
    mpl.rcParams['font.family'] = 'Nanum Brush Script OTF'
    return mpl.rcParams['font.family']

# %%
get_font()
# Out:
# NanumSquare Neo Bold
# Nanum CeorPirGeurSsi
# Nanum DdaDdeusHanJagByeor
# NanumSquare Neo OTF ExtraBold
# NanumSquare Neo Light
# Nanum HeuinGgoRiSuRi
# NanumBarunpenOTF
# Nanum JaBuSimJiU
# Nanum MuJinJangCe
# Nanum HaRamCe
# Nanum BaReunJeongSin
# NanumSquare Neo Regular
# Nanum EongGeongKwiCe
# Nanum HaNaSonGeurSsi
# Nanum GiBbeumBarkEum
# Nanum HimNaeRaNeunMarBoDan
# Nanum GangInHanWiRo
# Nanum MongDor
# Nanum SeHwaCe
# D2Coding ligature
# Nanum WaIrDeu
# Nanum DaeHanMinGugYeorSaCe
# Nanum DdaAgDanDan
# Nanum NaEuiANaeSonGeurSsi
# Nanum BaeEunHyeCe
# Nanum BeoDeuNaMu
# Nanum OeHarMeoNiGeurSsi
# Nanum JinJuBagGyeongACe
# Nanum KoKoCe
# Nanum YeDangCe
# Nanum OgBiCe
# Nanum BanJjagBanJjagByeor
# D2Coding ligature
# Nanum Pen Script OTF
# Nanum Pen Script
# NanumSquare Neo OTF Light
# Nanum BaReunHiPi
# NanumSquare Neo OTF Bold
# Nanum Brush Script OTF
# Nanum HyoNamNeurHwaITing
# Nanum EuiMiIssNeunHanGeur
# Nanum ABbaGeurSsi
# Nanum DaCaeSaRang
# D2Coding
# Nanum GgocNaeEum
# Nanum AnSsangCe
# Nanum HyeogICe
# Nanum HarABeoJiEuiNaNum
# D2Coding ligature
# NanumBarunpen
# Nanum BugGeugSeong
# NanumSquare Neo OTF Heavy
# Nanum SiUGwiYeoWeo
# NanumBarunpenOTF
# Nanum MiRaeNaMu
# Nanum MaGoCe
# Nanum OenSonJabIDoYeBbeo
# Nanum YeBbeunMinGyeongCe
# NanumSquare Neo Heavy
# Nanum SuJubEunDaeHagSaeng
# Nanum GangBuJangNimCe
# Nanum AInMamSonGeurSsi
# Nanum SonPyeonJiCe
# Nanum DdarEGeEomMaGa
# Nanum JarHaGoIssEo
# Nanum JungHagSaeng
# Nanum HeuiMangNuRi
# NanumBarunGothic YetHangul
# Nanum GeumEunBoHwa
# Nanum YuNiDdingDdangDdingDdang
# Nanum GgeuTeuMeoRiCe
# Nanum MasIssNeunCe
# Nanum SangHaeCanMiCe
# Nanum BaegEuiEuiCeonSa
# Nanum HyeJunCe
# Nanum SoMiCe
# Nanum NaMuJeongWeon
# Nanum GyuRiEuiIrGi
# Nanum JeongEunCe
# Nanum SeongSirCe
# Nanum BeomSomCe
# NanumBarunGothicOTF YetHangul
# Nanum BuJangNimNunCiCe
# Nanum NeuRisNeuRisCe
# Nanum YeorAHobEuiBanJjagIm
# Nanum Brush Script
# Nanum GimYuICe
# Nanum NaNeunIGyeoNaenDa
# NanumBarunpen
# Nanum NoRyeogHaNeunDongHeui
# NanumSquare Neo ExtraBold
# Nanum YaGeunHaNeunGimJuIm
# Nanum AReumDeuRiGgocNaMu
# Nanum DdoBagDdoBag
# Nanum DongHwaDdoBag
# Nanum YeorIrCe
# Nanum GaRamYeonGgoc
# Nanum GomSinCe
# Nanum GoDigANiGoGoDing
# Nanum HaNaDoeEoSonGeurSsi
# Nanum HaengBogHanDoBi
# Nanum JeomGgorCe
# Nanum AGiSaRangCe
# Nanum URiDdarSonGeurSsi
# Nanum KarGugSu
# Nanum BbangGuNiMamSonGeurSsi
# Nanum MuGungHwa
# Nanum HanYunCe
# Nanum SaRangHaeADeur
# Nanum BiSangCe
# Nanum SoBangGwanEuiGiDo
# Nanum SinHonBuBu
# Nanum DaSiSiJagHae
# NanumSquare Neo OTF Regular
# Nanum JangMiCe
# Nanum MiNiSonGeurSsi
# Nanum GarMaesGeur
# Nanum CoDingHeuiMang
# Nanum YeonJiCe
# Nanum DungGeunInYeon
# Nanum ABbaEuiYeonAePyeonJi
# Nanum YaCaeJangSuBaegGeumRye
# Nanum YeoReumGeurSsi
# Nanum DaJinCe
# Nanum SeACe
# Nanum DaeGwangYuRi
# Nanum AJumMaJaYu
# Nanum AmSeuTeReuDam
# Nanum DarEuiGweDo
# Nanum DaHaengCe
# Nanum SeGyeJeogInHanGeur
# Nanum EomMaSaRang
# Nanum GoRyeoGeurGgor
# ['Nanum Brush Script OTF']

# %%
# 기초통계량 확인하기
adr_df.describe()
# Out:
#                 인구밀도        총 사업체수  반경 1km 이내 불법주정차 단속 수           토지면적  \
# count   23213.000000  23213.000000          23213.000000   23213.000000
# mean    34900.199065     66.497480             21.409555     360.372390
# std     14909.802802     75.688845              8.303961    3905.284235
# min         0.000000      0.000000              2.000000       1.000000
# 25%     24129.400000     27.000000             15.000000     125.500000
# 50%     36796.500000     48.000000             22.000000     162.600000
# 75%     46032.500000     79.000000             28.000000     217.500000
# max    138678.800000   1448.000000             45.000000  501359.000000
#
#           공시지가_기준년월    공시지가(원/면적)       역과의최단거리  반경 1km 이내 주차장수
# count  23213.000000  2.321300e+04  23213.000000    23213.000000
# mean       3.999138  5.188785e+06    697.772326       94.107698
# std        0.077100  1.905761e+06    307.986961       32.106868
# min        0.000000  2.900000e+04      6.000000       14.000000
# 25%        4.000000  4.186000e+06    480.000000       68.000000
# 50%        4.000000  4.905000e+06    660.000000       93.000000
# 75%        4.000000  5.647000e+06    864.000000      116.000000
# max        5.000000  4.750000e+07   1907.000000      174.000000

# %%
# 이상치 확인하기
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.boxplot(adr_df)
plt.title("이상치확인하기",fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
def remove_outliers(df, column_name):
    '''
    이상치 제거하는 함수입니다.
    '''
    q1 = df[column_name].quantile(0.25)
    q3 = df[column_name].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df = df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]
    return df

# %%
# 이상치 제거하기
adr_df = remove_outliers(adr_df, "공시지가(원/면적)")

# %%
### 변수간 상관관계 분석하기
corr = adr_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,cmap=plt.cm.PuBu,annot=True, annot_kws = {"size" : 16},linecolor = "white",linewidths = 0.1)
plt.show()
# Out:
# c:\Users\gihun\Python_Data\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\gihun\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 정규성 검정하기

# %%
def get_shapiro(df,column_name):
    from scipy import stats
    # 샤피로 검정
    statistic, pvalue = stats.shapiro(df[column_name])
    # 결과 출력
    print(f'statistic: {statistic:.4f}, p-value: {pvalue:.6f}')
    if pvalue > 0.05:
        print('Data follows normal distribution')
    else:
        print('Data does not follow normal distribution')

# %%
for item in list(adr_df.columns):
    print(item)
    get_shapiro(adr_df,item) # 공시지가_기준년월은 범주형 변수이므로 제외하기
# Out:
# 인구밀도
# statistic: 0.9753, p-value: 0.000000
# Data does not follow normal distribution
# 총 사업체수
# statistic: 0.5461, p-value: 0.000000
# Data does not follow normal distribution
# 반경 1km 이내 불법주정차 단속 수
# statistic: 0.9650, p-value: 0.000000
# Data does not follow normal distribution
# 토지면적
# statistic: 0.0549, p-value: 0.000000
# Data does not follow normal distribution
# 공시지가_기준년월
# statistic: 0.0065, p-value: 0.000000
# Data does not follow normal distribution
# 공시지가(원/면적)
# statistic: 0.9860, p-value: 0.000000
# Data does not follow normal distribution
# 역과의최단거리
# statistic: 0.9692, p-value: 0.000000
# Data does not follow normal distribution
# 반경 1km 이내 주차장수
# statistic: 0.9791, p-value: 0.000000
# Data does not follow normal distribution
# c:\Users\gihun\Python_Data\lib\site-packages\scipy\stats\_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
def plot_histograms(df):
    for column in df.columns:
        plt.hist(df[column], bins=20)
        plt.title(column)
        plt.show()

# %%
plot_histograms(adr_df)

# %% [markdown]
# ### 양수 인것들만 로그 변환해서 데이터 분포 변환하기

# %%
# 로그 변환하기 전의 데이터프레임 복사
adr_df2 = adr_df.copy()

# %%
def log_transform(dataframe, columns):
    for column in columns:
        filtered = dataframe[column][dataframe[column] > 0] # filter out negative or zero values
        dataframe[column] = np.log(filtered) # apply log transformation
    return dataframe

# %%
log_df = log_transform(adr_df, adr_df.columns)
# Out:
# C:\Users\gihun\AppData\Local\Temp\ipykernel_19960\1113042258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[column] = np.log(filtered) # apply log transformation

# %%
plot_histograms(log_df)

# %%
log_df.dropna(inplace=True) # 로그변환후에 결측치 제거하기
# Out:
# c:\Users\gihun\Python_Data\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
log_df.to_excel("./data/preprocessed_광진구_데이터프레임.xlsx")
