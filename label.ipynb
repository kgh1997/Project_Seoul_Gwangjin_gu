# %%
import numpy as np
import pandas as pd

label = pd.read_excel("./data/광진구_공영주차장2.xlsx",index_col=0)
adr_df = pd.read_excel("./data/광진구_클러스터링.xlsx",index_col=0)
adr_df.drop(["토지면적","공시지가_기준년월","Cluster1",	"Cluster2",	"Cluster3",	"Cluster4",	"Cluster5",	"Cluster6", "Cluster7",	"Cluster8"], axis=1,inplace=True)

# %%
adr_df
# Out:
#                            인구밀도  총 사업체수  반경 1km 이내 불법주정차 단속 수  공시지가(원/면적)  \
# 지번주소
# 서울특별시 광진구 광장동  102   7067.70000     136                     2     6324000
# 서울특별시 광진구 광장동  104   7067.70000     136                     2     5097000
# 서울특별시 광진구 광장동  105   7067.70000     136                     2     5202000
# 서울특별시 광진구 광장동  106   7067.70000     136                     2     5097000
# 서울특별시 광진구 광장동  107   7067.70000     136                     2     5793000
# ...                         ...     ...                   ...         ...
# 서울특별시 광진구 화양동  95-5 52366.10000      44                    28     4346000
# 서울특별시 광진구 화양동  96-2 52366.10000      44                    31     4346000
# 서울특별시 광진구 화양동  97   52366.10000      44                    28     5095000
# 서울특별시 광진구 화양동  98-1 52366.10000      44                    28     5095000
# 서울특별시 광진구 화양동  99   52366.10000      44                    26     4847000
#
#                      역과의최단거리  반경 1km 이내 주차장수  Cluster9
# 지번주소
# 서울특별시 광진구 광장동  102      1144              41        -1
# 서울특별시 광진구 광장동  104      1166              41        -1
# 서울특별시 광진구 광장동  105      1068              41        -1
# 서울특별시 광진구 광장동  106      1038              41        -1
# 서울특별시 광진구 광장동  107      1011              42        -1
# ...                      ...             ...       ...
# 서울특별시 광진구 화양동  95-5      630              75         2
# 서울특별시 광진구 화양동  96-2      630              75         2
# 서울특별시 광진구 화양동  97        633              74         2
# 서울특별시 광진구 화양동  98-1      647              73         2
# 서울특별시 광진구 화양동  99        680              74         2
#
# [21657 rows x 7 columns]

# %%
label
# Out:
#                                                  도로명주소  \
# 지번주소
# 서울특별시 광진구 광장동 105   서울특별시 광진구 아차산로78길 63 (광장동, 워커힐현대빌)
# 서울특별시 광진구 광장동 110           서울특별시 광진구 아차산로78길 72 (광장동)
# 서울특별시 광진구 광장동 112           서울특별시 광진구 아차산로78길 90 (광장동)
# 서울특별시 광진구 광장동 126                                  NaN
# 서울특별시 광진구 광장동 127          서울특별시 광진구 아차산로78길 110 (광장동)
# ...                                                ...
# 서울특별시 광진구 화양동 6-2             서울특별시 광진구 아차산로 241 (화양동)
# 서울특별시 광진구 화양동 63-2                                 NaN
# 서울특별시 광진구 화양동 7-3             서울특별시 광진구 아차산로 242 (자양동)
# 서울특별시 광진구 화양동 8-27          서울특별시 광진구 동일로22길 101 (화양동)
# 서울특별시 광진구 화양동 8-36                                 NaN
#
#                                         주차장이름.pl_nm.  \
# 지번주소
# 서울특별시 광진구 광장동 105                         워커힐현대빌 주차장
# 서울특별시 광진구 광장동 110   학산코스모스텔 주차장(민영), 공영, 학산코스모스텔(공영)
# 서울특별시 광진구 광장동 112                        광진정보도서관 주차장
# 서울특별시 광진구 광장동 126                                큰나루
# 서울특별시 광진구 광장동 127                        리버힐오피스텔 주차장
# ...                                              ...
# 서울특별시 광진구 화양동 6-2                           연한빌딩 주차장
# 서울특별시 광진구 화양동 63-2                            화양동 공영
# 서울특별시 광진구 화양동 7-3                           한림타워 주차장
# 서울특별시 광진구 화양동 8-27                            웅진 주차장
# 서울특별시 광진구 화양동 8-36                               NaN
#
#                                일반인이용.pl_open_public.  \
# 지번주소
# 서울특별시 광진구 광장동 105            일반인 개방(19), 거주자 우선공간(6)
# 서울특별시 광진구 광장동 110   일반인 개방(61), 거주자 우선공간(11), 공영(61)
# 서울특별시 광진구 광장동 112                     미개방(18), 공영(1)
# 서울특별시 광진구 광장동 126                                NaN
# 서울특별시 광진구 광장동 127                  일반인 개방(91), 공영(6)
# ...                                              ...
# 서울특별시 광진구 화양동 6-2                 일반인 개방(46), 공영(47)
# 서울특별시 광진구 화양동 63-2                               NaN
# 서울특별시 광진구 화양동 7-3                                미개방
# 서울특별시 광진구 화양동 8-27                               미개방
# 서울특별시 광진구 화양동 8-36                               NaN
#
#                     계획주차면수.pl_num_space_planned.         주차장유형            x  \
# 지번주소
# 서울특별시 광진구 광장동 105                              6  민영주차장, 공영주차장 965583.56629
# 서울특별시 광진구 광장동 110                             11  민영주차장, 공영주차장 965584.06282
# 서울특별시 광진구 광장동 112                              1  민영주차장, 공영주차장 965601.43166
# 서울특별시 광진구 광장동 126                             13         공영주차장 965577.71333
# 서울특별시 광진구 광장동 127                              6  민영주차장, 공영주차장 965568.86722
# ...                                          ...           ...          ...
# 서울특별시 광진구 화양동 6-2                             47  민영주차장, 공영주차장 962028.58450
# 서울특별시 광진구 화양동 63-2                            44         공영주차장 962121.52245
# 서울특별시 광진구 화양동 7-3                            215  민영주차장, 공영주차장 961926.17437
# 서울특별시 광진구 화양동 8-27                            12  민영주차장, 공영주차장 962000.23430
# 서울특별시 광진구 화양동 8-36                             5         공영주차장 961986.13587
#
#                                y       위도        경도           소지역코드  \
# 지번주소
# 서울특별시 광진구 광장동 105  1950339.50762 37.55175 127.11036  11050630020301
# 서울특별시 광진구 광장동 110  1950294.18391 37.55135 127.11037  11050630020002
# 서울특별시 광진구 광장동 112  1950263.64320 37.55107 127.11057  11050630020002
# 서울특별시 광진구 광장동 126  1950180.55976 37.55032 127.11030  11050630020002
# 서울특별시 광진구 광장동 127  1950160.11097 37.55014 127.11020  11050630020002
# ...                          ...      ...       ...             ...
# 서울특별시 광진구 화양동 6-2  1949123.40643 37.54065 127.07018  11050530020005
# 서울특별시 광진구 화양동 63-2 1949637.25214 37.54529 127.07120  11050530020016
# 서울특별시 광진구 화양동 7-3  1949141.56620 37.54081 127.06902  11050530020005
# 서울특별시 광진구 화양동 8-27 1949177.80238 37.54114 127.06986  11050530020005
# 서울특별시 광진구 화양동 8-36 1949223.14900 37.54155 127.06969  11050530020005
#
#                           인구밀도  총 사업체수  지하철이름  반경 1km 이내 불법주정차 단속 수  \
# 지번주소
# 서울특별시 광진구 광장동 105   7067.70000     136   광나루역                     1
# 서울특별시 광진구 광장동 110   1458.40000     340   광나루역                     1
# 서울특별시 광진구 광장동 112   1458.40000     340   광나루역                     1
# 서울특별시 광진구 광장동 126   1458.40000     340   광나루역                     1
# 서울특별시 광진구 광장동 127   1458.40000     340   광나루역                     2
# ...                        ...     ...    ...                   ...
# 서울특별시 광진구 화양동 6-2  18152.80000     311  건대입구역                    11
# 서울특별시 광진구 화양동 63-2 58911.90000      12  건대입구역                    13
# 서울특별시 광진구 화양동 7-3  18152.80000     311  건대입구역                    10
# 서울특별시 광진구 화양동 8-27 18152.80000     311  건대입구역                    11
# 서울특별시 광진구 화양동 8-36 18152.80000     311  건대입구역                    12
#
#                          토지면적 공시지가_기준년월  공시지가(원/면적)  역과의최단거리  반경 1km 이내 주차장수
# 지번주소
# 서울특별시 광진구 광장동 105   848.80000  2022년01월     5202000      334              40
# 서울특별시 광진구 광장동 110   672.70000  2022년01월     6324000     1141              41
# 서울특별시 광진구 광장동 112  1587.40000  2022년01월     7102000     1122              41
# 서울특별시 광진구 광장동 126   512.00000  2022년01월     6037000     1028              41
# 서울특별시 광진구 광장동 127   856.80000  2022년01월     7720000     1000              41
# ...                       ...       ...         ...      ...             ...
# 서울특별시 광진구 화양동 6-2   111.60000  2022년01월    33834000      232             111
# 서울특별시 광진구 화양동 63-2  664.00000  2022년01월     3717000      606              71
# 서울특별시 광진구 화양동 7-3  2291.30000  2022년01월    18760000       79             107
# 서울특별시 광진구 화양동 8-27 1143.20000  2022년01월    11200000      203             105
# 서울특별시 광진구 화양동 8-36  996.40000  2022년01월     2036000      220             100
#
# [475 rows x 19 columns]

# %%
pd.options.display.float_format = '{:.5f}'.format # 지수표현 안보이게하기

# %% [markdown]
# ### 공영주차장 전처리

# %%
label = label[["인구밀도", "총 사업체수", "반경 1km 이내 불법주정차 단속 수", "공시지가(원/면적)", "역과의최단거리","반경 1km 이내 주차장수"]]

# %% [markdown]
# ### 공영주차장과 가장 밀접한 군집 추출하기

# %%
def get_scaler(df):
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    scaled_df = scaler.fit_transform(df.values)
    scaled_df = pd.DataFrame(data=scaled_df, index=df.index, columns=df.columns)
    return scaled_df

# %% [markdown]
# #### 스케일링하기

# %%
scaled_df = get_scaler(adr_df.drop(columns="Cluster9"))
scaled_label = get_scaler(label)

# %%
# 스케일링된 데이터프레임에 군집라벨값 합치기
scaled_df["Cluster9"] = adr_df["Cluster9"]

# %%
def get_distance(groupby_df, label, column_name):
    '''
    군집별로 정답 데이터와의 거리를 구하는 함수입니다.
    groupby_df: 군집 라벨 값이 포함된 데이터프레임
    label: 공영주차장의 데이터프레임
    column_name: 그룹으로 묶을 컬럼 이름인자
    '''
    import numpy as np
    import pandas as pd

    groupby_df = groupby_df.groupby(column_name).mean() # 각 군집별로 평균값을 가진 데이터프레임
    print(groupby_df)
    label_means = label.mean() # 정답 데이터의 평균
    print(label_means)
    distances = []
    for column in groupby_df.columns:
        distance =  np.sqrt(np.square(groupby_df.groupby(column_name).mean()[column] - label.mean()[column]))
        print(distance)
        distances.append(distance)
    distances = pd.DataFrame(distances).sum()
    return distances

# %%
get_distance(scaled_df, scaled_label, "Cluster9")
# Out:
#              인구밀도   총 사업체수  반경 1km 이내 불법주정차 단속 수  공시지가(원/면적)  역과의최단거리  \
# Cluster9
# -1       -0.67696  0.12869              -0.20620    -0.17894  0.35137
#  0        0.47688 -0.17715              -1.08561    -0.36552 -0.90921
#  1        0.82069 -0.66787              -0.06195    -0.23356 -0.15879
#  2        0.84282 -0.35987               0.55901     0.31639 -0.24311
#  3        0.80664 -0.59341              -1.04201    -0.96479  0.19361
#  4        0.69948 -0.28375              -0.63130     0.47494  2.06136
#  5        0.59409 -0.46899               1.19401    -0.47173 -0.47473
#  6       -0.43144  0.33623               0.12223     0.43104  0.00222
#  7       -0.82773  0.94633               0.56708     0.35999 -0.80216
#  8       -0.44527  0.33224              -0.45927     0.86673  1.15822
#
#           반경 1km 이내 주차장수
# Cluster9
# -1              -0.09362
#  0              -0.22800
#  1              -0.75931
#  2              -1.05315
#  3               0.38883
#  4               0.54487
#  5               1.40320
#  6              -1.00977
#  7               0.81519
#  8               0.53666
# 인구밀도                   -0.00000
# 총 사업체수                  0.00000
# 반경 1km 이내 불법주정차 단속 수   -0.00000
# 공시지가(원/면적)             -0.00000
# 역과의최단거리                -0.00000
# 반경 1km 이내 주차장수          0.00000
# dtype: float64
# Cluster9
# -1   0.67696
#  0   0.47688
#  1   0.82069
#  2   0.84282
#  3   0.80664
#  4   0.69948
#  5   0.59409
#  6   0.43144
#  7   0.82773
#  8   0.44527
# Name: 인구밀도, dtype: float64
# Cluster9
# -1   0.12869
#  0   0.17715
#  1   0.66787
#  2   0.35987
#  3   0.59341
#  4   0.28375
#  5   0.46899
#  6   0.33623
#  7   0.94633
#  8   0.33224
# Name: 총 사업체수, dtype: float64
# Cluster9
# -1   0.20620
#  0   1.08561
#  1   0.06195
#  2   0.55901
#  3   1.04201
#  4   0.63130
#  5   1.19401
#  6   0.12223
#  7   0.56708
#  8   0.45927
# Name: 반경 1km 이내 불법주정차 단속 수, dtype: float64
# Cluster9
# -1   0.17894
#  0   0.36552
#  1   0.23356
#  2   0.31639
#  3   0.96479
#  4   0.47494
#  5   0.47173
#  6   0.43104
#  7   0.35999
#  8   0.86673
# Name: 공시지가(원/면적), dtype: float64
# Cluster9
# -1   0.35137
#  0   0.90921
#  1   0.15879
#  2   0.24311
#  3   0.19361
#  4   2.06136
#  5   0.47473
#  6   0.00222
#  7   0.80216
#  8   1.15822
# Name: 역과의최단거리, dtype: float64
# Cluster9
# -1   0.09362
#  0   0.22800
#  1   0.75931
#  2   1.05315
#  3   0.38883
#  4   0.54487
#  5   1.40320
#  6   1.00977
#  7   0.81519
#  8   0.53666
# Name: 반경 1km 이내 주차장수, dtype: float64
# Cluster9
# -1   1.63578
#  0   3.24237
#  1   2.70217
#  2   3.37435
#  3   3.98929
#  4   4.69571
#  5   4.60676
#  6   2.33292
#  7   4.31848
#  8   3.79838
# dtype: float64

# %%
adr_df[adr_df["Cluster9"]==6].mean()
# Out:
# 인구밀도                     29393.86276
# 총 사업체수                      83.06091
# 반경 1km 이내 불법주정차 단속 수        22.26165
# 공시지가(원/면적)             5306437.47116
# 역과의최단거리                    708.26581
# 반경 1km 이내 주차장수              61.78311
# Cluster9                     6.00000
# dtype: float64

# %%
label.mean()
# Out:
# 인구밀도                     29304.31432
# 총 사업체수                      80.16632
# 반경 1km 이내 불법주정차 단속 수         9.45684
# 공시지가(원/면적)             4914934.87158
# 역과의최단거리                    723.53684
# 반경 1km 이내 주차장수              93.47789
# dtype: float64

# %%
df_6 = adr_df[adr_df["Cluster9"]==6] # 6번 군집 추출
scaled_df_6 = get_scaler(df_6.drop("Cluster9",axis=1)) # 스케일링 하기
scaled_df_6.reset_index(inplace=True)

# %%
# 정답 데이터와 제일 근접한 상위 100개 추출
df = pd.DataFrame(get_distance(scaled_df_6,scaled_label,"지번주소").sort_values()[:100])
df
# Out:
#                           인구밀도   총 사업체수  반경 1km 이내 불법주정차 단속 수  공시지가(원/면적)  \
# 지번주소
# 서울특별시 광진구 광장동  131-1  -1.30377 -0.44413              -2.46336     2.31850
# 서울특별시 광진구 광장동  137    -1.30377 -0.44413              -2.46336     2.24606
# 서울특별시 광진구 광장동  148-11 -1.30377 -0.44413              -2.46336     1.28329
# 서울특별시 광진구 광장동  148-21 -1.30377 -0.44413              -2.46336    -0.57806
# 서울특별시 광진구 광장동  148-22 -1.30377 -0.44413              -2.46336    -0.79079
# ...                        ...      ...                   ...         ...
# 서울특별시 광진구 화양동  9-80    1.03549  0.70208               0.23449     0.56534
# 서울특별시 광진구 화양동  9-82    1.03549  0.70208               0.23449    -0.10493
# 서울특별시 광진구 화양동  9-83    1.03549  0.70208               0.50427    -0.15261
# 서울특별시 광진구 화양동  9-84    1.03549  0.70208              -0.30508    -0.15261
# 서울특별시 광진구 화양동  9-9     1.03549  0.70208               0.23449     0.56534
#
#                        역과의최단거리  반경 1km 이내 주차장수
# 지번주소
# 서울특별시 광진구 광장동  131-1   0.69455        -1.44585
# 서울특별시 광진구 광장동  137     0.41368        -1.44585
# 서울특별시 광진구 광장동  148-11 -0.13942        -1.44585
# 서울특별시 광진구 광장동  148-21  0.37479        -1.44585
# 서울특별시 광진구 광장동  148-22  0.35318        -1.44585
# ...                        ...             ...
# 서울특별시 광진구 화양동  9-80   -1.86787         2.20841
# 서울특별시 광진구 화양동  9-82   -1.96726         2.42766
# 서울특별시 광진구 화양동  9-83   -2.27838         2.72000
# 서울특별시 광진구 화양동  9-84   -2.24813         2.79309
# 서울특별시 광진구 화양동  9-9    -1.97158         2.35458
#
# [2167 rows x 6 columns]
# 인구밀도                   -0.00000
# 총 사업체수                  0.00000
# 반경 1km 이내 불법주정차 단속 수   -0.00000
# 공시지가(원/면적)             -0.00000
# 역과의최단거리                -0.00000
# 반경 1km 이내 주차장수          0.00000
# dtype: float64
# 지번주소
# 서울특별시 광진구 광장동  131-1    1.30377
# 서울특별시 광진구 광장동  137      1.30377
# 서울특별시 광진구 광장동  148-11   1.30377
# 서울특별시 광진구 광장동  148-21   1.30377
# 서울특별시 광진구 광장동  148-22   1.30377
#                           ...
# 서울특별시 광진구 화양동  9-80     1.03549
# 서울특별시 광진구 화양동  9-82     1.03549
# 서울특별시 광진구 화양동  9-83     1.03549
# 서울특별시 광진구 화양동  9-84     1.03549
# 서울특별시 광진구 화양동  9-9      1.03549
# Name: 인구밀도, Length: 2167, dtype: float64
# 지번주소
# 서울특별시 광진구 광장동  131-1    0.44413
# 서울특별시 광진구 광장동  137      0.44413
# 서울특별시 광진구 광장동  148-11   0.44413
# 서울특별시 광진구 광장동  148-21   0.44413
# 서울특별시 광진구 광장동  148-22   0.44413
#                           ...
# 서울특별시 광진구 화양동  9-80     0.70208
# 서울특별시 광진구 화양동  9-82     0.70208
# 서울특별시 광진구 화양동  9-83     0.70208
# 서울특별시 광진구 화양동  9-84     0.70208
# 서울특별시 광진구 화양동  9-9      0.70208
# Name: 총 사업체수, Length: 2167, dtype: float64
# 지번주소
# 서울특별시 광진구 광장동  131-1    2.46336
# 서울특별시 광진구 광장동  137      2.46336
# 서울특별시 광진구 광장동  148-11   2.46336
# 서울특별시 광진구 광장동  148-21   2.46336
# 서울특별시 광진구 광장동  148-22   2.46336
#                           ...
# 서울특별시 광진구 화양동  9-80     0.23449
# 서울특별시 광진구 화양동  9-82     0.23449
# 서울특별시 광진구 화양동  9-83     0.50427
# 서울특별시 광진구 화양동  9-84     0.30508
# 서울특별시 광진구 화양동  9-9      0.23449
# Name: 반경 1km 이내 불법주정차 단속 수, Length: 2167, dtype: float64
# 지번주소
# 서울특별시 광진구 광장동  131-1    2.31850
# 서울특별시 광진구 광장동  137      2.24606
# 서울특별시 광진구 광장동  148-11   1.28329
# 서울특별시 광진구 광장동  148-21   0.57806
# 서울특별시 광진구 광장동  148-22   0.79079
#                           ...
# 서울특별시 광진구 화양동  9-80     0.56534
# 서울특별시 광진구 화양동  9-82     0.10493
# 서울특별시 광진구 화양동  9-83     0.15261
# 서울특별시 광진구 화양동  9-84     0.15261
# 서울특별시 광진구 화양동  9-9      0.56534
# Name: 공시지가(원/면적), Length: 2167, dtype: float64
# 지번주소
# 서울특별시 광진구 광장동  131-1    0.69455
# 서울특별시 광진구 광장동  137      0.41368
# 서울특별시 광진구 광장동  148-11   0.13942
# 서울특별시 광진구 광장동  148-21   0.37479
# 서울특별시 광진구 광장동  148-22   0.35318
#                           ...
# 서울특별시 광진구 화양동  9-80     1.86787
# 서울특별시 광진구 화양동  9-82     1.96726
# 서울특별시 광진구 화양동  9-83     2.27838
# 서울특별시 광진구 화양동  9-84     2.24813
# 서울특별시 광진구 화양동  9-9      1.97158
# Name: 역과의최단거리, Length: 2167, dtype: float64
# 지번주소
# 서울특별시 광진구 광장동  131-1    1.44585
# 서울특별시 광진구 광장동  137      1.44585
# 서울특별시 광진구 광장동  148-11   1.44585
# 서울특별시 광진구 광장동  148-21   1.44585
# 서울특별시 광진구 광장동  148-22   1.44585
#                           ...
# 서울특별시 광진구 화양동  9-80     2.20841
# 서울특별시 광진구 화양동  9-82     2.42766
# 서울특별시 광진구 화양동  9-83     2.72000
# 서울특별시 광진구 화양동  9-84     2.79309
# 서울특별시 광진구 화양동  9-9      2.35458
# Name: 반경 1km 이내 주차장수, Length: 2167, dtype: float64
#                             0
# 지번주소
# 서울특별시 광진구 구의동  70-22  0.98315
# 서울특별시 광진구 군자동  346-20 1.04581
# 서울특별시 광진구 구의동  70-25  1.09592
# 서울특별시 광진구 구의동  70-23  1.11935
# 서울특별시 광진구 군자동  359-3  1.17589
# ...                       ...
# 서울특별시 광진구 화양동  123-1  2.20585
# 서울특별시 광진구 화양동  24-4   2.21243
# 서울특별시 광진구 자양동  196-1  2.21376
# 서울특별시 광진구 군자동  354-4  2.21576
# 서울특별시 광진구 자양동  766    2.22821
#
# [100 rows x 1 columns]

# %% [markdown]
# ### 가장 가까운 군집 내에서 후보지 선정하기

# %%
cad_df = pd.read_excel("./data/광진구_공영주차장후보지.xlsx",index_col=0)

# %%
import folium
map = folium.Map(location=[cad_df['위도'].mean(), cad_df['경도'].mean()], zoom_start=14)
for index, row in cad_df.iterrows():
    folium.Marker(location=[row['위도'], row['경도']]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_467b73f9dbb970c8ae478cfd8e57bd86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_467b73f9dbb970c8ae478cfd8e57bd86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_467b73f9dbb970c8ae478cfd8e57bd86 = L.map(
#                 &quot;map_467b73f9dbb970c8ae478cfd8e57bd86&quot;,
#                 {
#                     center: [37.547448359, 127.07521657],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a68f86ecaa736fca614e82027a1f7f2c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_46b29416722568225c4e508f775dfd5f = L.marker(
#                 [37.5480376, 127.0894462],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_dfcecf215d01fde940b1dbf265e9175f = L.marker(
#                 [37.5496746, 127.0703375],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_bc89b484f4aa642c641423ae24606676 = L.marker(
#                 [37.547878, 127.0891791],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_189d55a3cc60d98b86fcfa6e06a7992a = L.marker(
#                 [37.5479435, 127.0893416],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_8dab7fb0d66a8f43ed78461ea36eb1b8 = L.marker(
#                 [37.5493696, 127.0704213],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_0e89a7fbb5666219eb793f3dec73456b = L.marker(
#                 [37.5479022, 127.0897024],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_891fb33cf02b7e27759ca671eda77e2e = L.marker(
#                 [37.5480222, 127.0897578],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_4235391e85c5c233bff89a10358a1c4d = L.marker(
#                 [37.5477624, 127.0894235],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_7403e59ad5ce126e9141a1d4a02d7a9e = L.marker(
#                 [37.5477913, 127.0890136],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_cd7976e29064e789c3f1f84b65246e2d = L.marker(
#                 [37.5478505, 127.0895569],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_13c4c4eaf5053d89b51359e7cb9abe3d = L.marker(
#                 [37.5487324, 127.0688397],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_d7df974471376b1b1d947f62c02489a9 = L.marker(
#                 [37.5487871, 127.0689719],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_20067344ae8482161582dc0308e07392 = L.marker(
#                 [37.5485974, 127.0689123],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_933423416b556e5a2a0184b2ad324a99 = L.marker(
#                 [37.5486665, 127.0690406],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_2e6d0107763d0f7061501064d25295fe = L.marker(
#                 [37.5485428, 127.0691107],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_263018e31059450e72b7c8b96d873ed0 = L.marker(
#                 [37.5488459, 127.0687695],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_14794d161e703cb7de36e504b0e69cc5 = L.marker(
#                 [37.54890160000001, 127.0689],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_a83b0575b2847f364dc14d5900b2cf30 = L.marker(
#                 [37.551012, 127.0708612],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_9a76c3e29badd382b064d56d556576a3 = L.marker(
#                 [37.549874, 127.0701004],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var marker_7804f3484a4d857b36459937046c41a3 = L.marker(
#                 [37.549159, 127.0701954],
#                 {}
#             ).addTo(map_467b73f9dbb970c8ae478cfd8e57bd86);
#
#
#             var ma
