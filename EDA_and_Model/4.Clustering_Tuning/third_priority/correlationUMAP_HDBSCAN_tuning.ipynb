# %%
import numpy as np
import pandas as pd

original_path = "C:/Python_practice/DL_project/gwangjin_contest/EDA_and_Model/3.LogAndRobustScaled_UMAP_Clustering_Tuning/"

# %%
train_df_umap = pd.read_csv(original_path + "HDBSCAN_cluster_without_noise_correlation.csv", index_col=0)
del train_df_umap['HDBSCAN_cluster_without_noise']
train_df_umap.head(5)
# Out:
#                        UMAP1     UMAP2
# 지번주소
# 서울특별시 광진구 광장동  104  5.477084  9.608908
# 서울특별시 광진구 광장동  105  5.204193  9.341188
# 서울특별시 광진구 광장동  106  7.037618  7.847633
# 서울특별시 광진구 광장동  107  7.150563  7.880716
# 서울특별시 광진구 광장동  108  7.473243  7.318750

# %% [markdown]
# ## hdbscan 파라미터 튜닝

# %%
# 실루엣 점수 계산 함수
def silhouette(clustering_result) : 
    from sklearn.metrics import silhouette_score

    # 클러스터링 결과에서 노이즈 포인트 제외한 데이터와 클러스터 레이블 추출
    X = clustering_result.loc[clustering_result['HDBSCAN_cluster_without_noise'] != -1, ['UMAP1', 'UMAP2']]
    labels = clustering_result.loc[clustering_result['HDBSCAN_cluster_without_noise'] != -1, 'HDBSCAN_cluster_without_noise']

    # 실루엣 점수 계산
    silhouette_avg = silhouette_score(X, labels)

    return silhouette_avg

# %%
# 노이즈 포인트를 제외한 클러스터링 결과
def get_without_noise_hdbscan(train_df_umap) :
    from hdbscan import HDBSCAN

    min_cluster_size = range(100, 1001, 100)
    min_samples = range(3, 16, 2)
    cluster_selection_epsilon = [float(x) for x in np.around(np.arange(0.1, 1.1, 0.1), decimals=1)]
    result=[] # 결과 저장
    for a in min_cluster_size : 
        for b in min_samples : 
            for c in cluster_selection_epsilon : 
                # HDBSCAN 객체 생성 및 매개 변수 설정
                hdbscan_clustering = HDBSCAN(
                    min_cluster_size=a,  # 클러스터 최소 크기 조정 -> 이 값보다 작은 클러스터는 노이즈로 간주 (값이 작을수록 군집 수 증가)
                    min_samples=b,  # 이웃의 최소 개수 조정 
                                    # (값 늘리면 : 더 안정적인 클러스터 생성 + 노이즈 감소, but 군집 수 감소)
                                    # (값 줄이면 : 더 많은 클러스터가 생성)
                    cluster_selection_epsilon=c  # 클러스터 간의 최소 거리 조정 (값 늘리면 : 군집 수 감소 | 값 줄이면 : 군집 수 증가)
                )

                # HDBSCAN 학습
                hdbscan_clustering.fit(train_df_umap)

                # 클러스터링 결과를 train_df_umap DataFrame에 추가
                train_df_umap['HDBSCAN_cluster_without_noise'] = hdbscan_clustering.labels_
                train_df_umap = train_df_umap[train_df_umap['HDBSCAN_cluster_without_noise'] != -1]  # 노이즈 포인트 제거

                # 실루엣 점수가 0.75 초과인 것만 저장
                silhouette_avg = silhouette(train_df_umap)
                if silhouette_avg > 0.30 :
                    result.append(f"silhouette_avg: {silhouette_avg}, min_cluster_size: {a}, min_samples: {b}, cluster_selection_epsilon: {c}")

    return result

best_parms = get_without_noise_hdbscan(train_df_umap)
best_parms
# Out:
# C:\Users\dohee\AppData\Local\Temp\ipykernel_15276\1387983333.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_umap['HDBSCAN_cluster_without_noise'] = hdbscan_clustering.labels_
# ['silhouette_avg: 0.4303486187098472, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.43420393269761154, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.43420393269761154, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4413384558759278, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.44221909593277964, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.44221909593277964, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4387123389605127, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4387123389605127, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.43876534970419145, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4453505356950449, min_cluster_size: 100, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4453505356950449, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.45469319200160974, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.44789474190129425, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.44789474190129425, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.45206738965089677, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4552455179276913, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.45539933860836396, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4551271798538732, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4551271798538732, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.45543480284718857, min_cluster_size: 100, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.44837301511857464, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.44837301511857464, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.45118008978034746, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4496405576753367, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.45048591467332844, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4443320579271568, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4443320579271568, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.45075583060064756, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.45470771586810904, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.45470771586810904, min_cluster_size: 100, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.45437805582848145, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.45437805582848145, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.45437805582848145, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.457348339183951, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.457348339183951, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.457348339183951, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.457348339183951, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.457348339183951, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.457348339183951, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.46323999590748766, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.45058480371683673, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.45058480371683673, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.45058480371683673, min_cluster_size: 100, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.45058480371683673, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.45058480371683673, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4615339725887364, min_cluster_size: 100, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.35318579821209345, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.3339234526059351, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.39454470395599966, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.43125027918824, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4377213089911767, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4433841120302506, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4433841120302506, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.44133478085309874, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4325622660013212, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4459171907974631, min_cluster_size: 200, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4527270463825193, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.45873377571074275, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.45873377571074275, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.45873377571074275, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.45862845621485226, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4699731621202008, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4699731621202008, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4699870328301999, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.47401958365676783, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4754703714563641, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4794135149007743, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.48611880043048483, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.48611880043048483, min_cluster_size: 200, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.48611880043048483, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.48611880043048483, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.48611880043048483, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4820600764382413, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4757129221481408, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4815389905861042, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4815389905861042, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4815389905861042, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4861583630414683, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4861583630414683, min_cluster_size: 200, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4861583630414683, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4853652616911401, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4916148026398848, min_cluster_size: 200, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.45955759320758244, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.42779100966574113, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.42779100966574113, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4332252982178499, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.45712870167729114, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.44893205004640435, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.5085430310200602, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4918688170058491, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4918688170058491, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4918688170058491, min_cluster_size: 300, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4918688170058491, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4918688170058491, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4918688170058491, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4918688170058491, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.5092933309694853, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.5092933309694853, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.5092933309694853, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.5092933309694853, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4928316456035793, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4682407794468641, min_cluster_size: 300, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4682407794468641, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4739590811815074, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.4987170426914959, min_cluster_size: 300, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.548688145855025, min_cluster_size: 400, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6032781174955044, min_cluster_size: 500, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6023289052605799, min_cluster_size: 600, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.5639437553290783, min_cluster_size: 700, min_samples: 3, cluster_selection_epsilon: 1.0',
# ...
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 800, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 800, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 800, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 800, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 900, min_samples: 15, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 3, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 5, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 7, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 9, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 11, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 13, cluster_selection_epsilon: 1.0',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.1',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.2',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.3',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.4',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.5',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.6',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.7',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.8',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 0.9',
#  'silhouette_avg: 0.6086931769765763, min_cluster_size: 1000, min_samples: 15, cluster_selection_epsilon: 1.0']

# %%
best_param = max(best_parms, key=lambda x: x.split(",")[0].split(":")[1])
print("Best params: " + best_param)
# Out:
# Best params: silhouette_avg: 0.6086931769765763, min_cluster_size: 800, min_samples: 9, cluster_selection_epsilon: 0.2

# %%
# best_param 데이터프레임으로 변환
df = pd.DataFrame({'params': best_parms})

df[['silhouette_avg', 'min_cluster_size', 'min_samples', 'cluster_selection_epsilon']] = df['params'].str.extract(r'silhouette_avg: ([\d\.]+), min_cluster_size: (\d+), min_samples: (\d+), cluster_selection_epsilon: ([\d\.]+)')
df.drop('params', axis=1, inplace=True)
df = df.astype({'silhouette_avg': 'float64', 'min_cluster_size': 'int64', 'min_samples': 'int64', 'cluster_selection_epsilon': 'float64'})
df
# Out:
#      silhouette_avg  min_cluster_size  min_samples  cluster_selection_epsilon
# 0          0.430349               100            3                        0.1
# 1          0.434204               100            3                        0.2
# 2          0.434204               100            3                        0.3
# 3          0.441338               100            3                        0.4
# 4          0.442219               100            3                        0.5
# ..              ...               ...          ...                        ...
# 695        0.608693              1000           15                        0.6
# 696        0.608693              1000           15                        0.7
# 697        0.608693              1000           15                        0.8
# 698        0.608693              1000           15                        0.9
# 699        0.608693              1000           15                        1.0
#
# [700 rows x 4 columns]

# %%
df.to_excel('C:/Python_practice/DL_project/gwangjin_contest/EDA_and_Model/4.Clustering_Tuning/third_priority/HDBSCAN_2_best_params.xlsx', index=False)

# %% [markdown]
# ## best 파라미터로 클러스터링 결과 확인

# %%
train_df_umap = pd.read_csv(original_path + "HDBSCAN_cluster_without_noise_correlation.csv", index_col=0)
del train_df_umap['HDBSCAN_cluster_without_noise']

# %%
# 노이즈 포인트를 제외한 클러스터링 결과
def get_without_noise_hdbscan(train_df_umap) :
    from hdbscan import HDBSCAN

    # HDBSCAN 객체 생성 및 매개 변수 설정 (min_cluster_size 등)
    hdbscan_clustering = HDBSCAN(
        min_cluster_size=800,
        min_samples=15,
        cluster_selection_epsilon=0.4
    )

    # UMAP으로 축소된 데이터(train_df_umap)에 HDBSCAN 적용
    hdbscan_clustering.fit(train_df_umap)

    # 모델 저장
    import pickle

    with open("C:/Python_practice/DL_project/gwangjin_contest/EDA_and_Model/4.Clustering_Tuning/second_priority/LogAndRobustScaled_UMAP_HDBSCAN_correlation_v2.pkl", "wb") as file:
        pickle.dump(hdbscan_clustering, file)


    # 클러스터링 결과를 train_df_umap DataFrame에 추가
    train_df_umap['HDBSCAN_cluster_without_noise'] = hdbscan_clustering.labels_
    train_df_umap = train_df_umap[train_df_umap['HDBSCAN_cluster_without_noise'] != -1]  # 노이즈 포인트 제거
    
    return train_df_umap

get_without_noise_hdbscan = get_without_noise_hdbscan(train_df_umap)
get_without_noise_hdbscan
# Out:
#                          UMAP1     UMAP2  HDBSCAN_cluster_without_noise
# 지번주소
# 서울특별시 광진구 광장동  104    5.477084  9.608908                              3
# 서울특별시 광진구 광장동  105    5.204193  9.341188                              3
# 서울특별시 광진구 광장동  106    7.037618  7.847633                              3
# 서울특별시 광진구 광장동  107    7.150563  7.880716                              3
# 서울특별시 광진구 광장동  108    7.473243  7.318750                              3
# ...                        ...       ...                            ...
# 서울특별시 광진구 화양동  94-61  5.499650  2.292994                              1
# 서울특별시 광진구 화양동  94-73  6.381227  2.596370                              1
# 서울특별시 광진구 화양동  95-3   3.569470 -0.081930                              2
# 서울특별시 광진구 화양동  96-2   3.642701 -0.052629                              2
# 서울특별시 광진구 화양동  99     2.493755 -0.869789                              2
#
# [15690 rows x 3 columns]

# %%
# 실루엣 점수 계산 함수
def silhouette(clustering_result) : 
    from sklearn.metrics import silhouette_score

    # 클러스터링 결과에서 노이즈 포인트 제외한 데이터와 클러스터 레이블 추출
    X = clustering_result.loc[clustering_result['HDBSCAN_cluster_without_noise'] != -1, ['UMAP1', 'UMAP2']]
    labels = clustering_result.loc[clustering_result['HDBSCAN_cluster_without_noise'] != -1, 'HDBSCAN_cluster_without_noise']

    # 실루엣 점수 계산
    silhouette_avg = silhouette_score(X, labels)

    return silhouette_avg

from sklearn.metrics import davies_bouldin_score, calinski_harabasz_score
from sklearn.neighbors import DistanceMetric

# Dunn 지수 계산 함수
def dunn(clustering_result):
    dist = DistanceMetric.get_metric('euclidean')
    labels = clustering_result['HDBSCAN_cluster_without_noise']
    clusters = np.unique(labels)
    centroids = [np.mean(clustering_result.loc[labels==i, ['UMAP1', 'UMAP2']], axis=0) for i in clusters]
    max_intracluster_distances = [np.max(dist.pairwise(clustering_result.loc[labels==i, ['UMAP1', 'UMAP2']])) for i in clusters]
    min_intercluster_distances = []
    for i, c1 in enumerate(centroids):
        for j, c2 in enumerate(centroids):
            if i < j:
                dist_ij = dist.pairwise([c1, c2])[0][1]
                min_intercluster_distances.append(dist_ij)
    return np.min(min_intercluster_distances) / np.max(max_intracluster_distances)

# Calinski-Harabasz 지수 계산 함수
def calinski_harabasz(clustering_result):
    labels = clustering_result['HDBSCAN_cluster_without_noise']
    return calinski_harabasz_score(clustering_result[['UMAP1', 'UMAP2']], labels)

# Dunn 지수와 Calinski-Harabasz 지수 계산
sil_score = silhouette(get_without_noise_hdbscan)
dunn_score = dunn(get_without_noise_hdbscan)
ch_score = calinski_harabasz(get_without_noise_hdbscan)

# 출력
print(f"실루엣 score: {sil_score}")
print(f"Dunn score: {dunn_score:.4f}")
print(f"Calinski-Harabasz score: {ch_score:.4f}")
# Out:
# C:\Users\dohee\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_distance_metric.py:10: FutureWarning: sklearn.neighbors.DistanceMetric has been moved to sklearn.metrics.DistanceMetric in 1.0. This import path will be removed in 1.3
#   warnings.warn(
# 실루엣 score: 0.41883503313215487
# Dunn score: 0.3505
# Calinski-Harabasz score: 16416.2734

# %%
get_without_noise_hdbscan.to_csv('C:/Python_practice/DL_project/gwangjin_contest/EDA_and_Model/4.Clustering_Tuning/third_priority/LogAndRobustScaled_correlationUMAP_HDBSCAN_v2.csv')

# %%
# 군집화 결과 시각화
def visualization_data(clustering_result):
    import matplotlib.pyplot as plt
    # 노이즈 포인트 제외
    clustered = (clustering_result['HDBSCAN_cluster_without_noise'] >= 0)
    
    plt.scatter(clustering_result[clustered]['UMAP1'],
                clustering_result[clustered]['UMAP2'],
                c=clustering_result[clustered]['HDBSCAN_cluster_without_noise'],
                s=0.1,
                cmap='Spectral')
    plt.show()
    
get_without_noise_hdbscan_v = visualization_data(get_without_noise_hdbscan)
get_without_noise_hdbscan_v

# %% [markdown]
# <hr>

# %% [markdown]
# ## 재시도

# %%
train_df_umap = pd.read_csv(original_path + "HDBSCAN_cluster_without_noise_correlation.csv", index_col=0)
del train_df_umap['HDBSCAN_cluster_without_noise']

# %%
# 노이즈 포인트를 제외한 클러스터링 결과
def get_without_noise_hdbscan(train_df_umap) :
    from hdbscan import HDBSCAN

    # HDBSCAN 객체 생성 및 매개 변수 설정 (min_cluster_size 등)
    hdbscan_clustering = HDBSCAN(
        min_cluster_size=800,
        min_samples=9,
        cluster_selection_epsilon=0.1
    )

    # UMAP으로 축소된 데이터(train_df_umap)에 HDBSCAN 적용
    hdbscan_clustering.fit(train_df_umap)

    # 모델 저장
    import pickle

    with open("C:/Python_practice/DL_project/gwangjin_contest/EDA_and_Model/4.Clustering_Tuning/third_priority/LogAndRobustScaled_UMAP_HDBSCAN_correlation_v4.pkl", "wb") as file:
        pickle.dump(hdbscan_clustering, file)


    # 클러스터링 결과를 train_df_umap DataFrame에 추가
    train_df_umap['HDBSCAN_cluster_without_noise'] = hdbscan_clustering.labels_
    train_df_umap = train_df_umap[train_df_umap['HDBSCAN_cluster_without_noise'] != -1]  # 노이즈 포인트 제거
    
    return train_df_umap

get_without_noise_hdbscan = get_without_noise_hdbscan(train_df_umap)
get_without_noise_hdbscan
# Out:
#                          UMAP1     UMAP2  HDBSCAN_cluster_without_noise
# 지번주소
# 서울특별시 광진구 광장동  104    5.477084  9.608908                              1
# 서울특별시 광진구 광장동  105    5.204193  9.341188                              1
# 서울특별시 광진구 광장동  106    7.037618  7.847633                              1
# 서울특별시 광진구 광장동  107    7.150563  7.880716                              1
# 서울특별시 광진구 광장동  108    7.473243  7.318750                              1
# ...                        ...       ...                            ...
# 서울특별시 광진구 화양동  94-61  5.499650  2.292994                              5
# 서울특별시 광진구 화양동  94-73  6.381227  2.596370                              5
# 서울특별시 광진구 화양동  95-3   3.569470 -0.081930                              4
# 서울특별시 광진구 화양동  96-2   3.642701 -0.052629                              4
# 서울특별시 광진구 화양동  99     2.493755 -0.869789                              4
#
# [15652 rows x 3 columns]

# %%
# Dunn 지수와 Calinski-Harabasz 지수 계산
sil_score = silhouette(get_without_noise_hdbscan)
dunn_score = dunn(get_without_noise_hdbscan)
ch_score = calinski_harabasz(get_without_noise_hdbscan)

# 출력
print(f"실루엣 score: {sil_score}")
print(f"Dunn score: {dunn_score:.4f}")
print(f"Calinski-Harabasz score: {ch_score:.4f}")
# Out:
# C:\Users\dohee\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_distance_metric.py:10: FutureWarning: sklearn.neighbors.DistanceMetric has been moved to sklearn.metrics.DistanceMetric in 1.0. This import path will be removed in 1.3
#   warnings.warn(
# 실루엣 score: 0.42213112431715366
# Dunn score: 0.3505
# Calinski-Harabasz score: 16589.2030

# %%
get_without_noise_hdbscan_v = visualization_data(get_without_noise_hdbscan)
get_without_noise_hdbscan_v

# %%
get_without_noise_hdbscan.to_csv('C:/Python_practice/DL_project/gwangjin_contest/EDA_and_Model/4.Clustering_Tuning/LogAndRobustScaled_correlationUMAP_HDBSCAN_v4.csv')
